# %% [markdown]
# # 22. 자주 사용하는 Python Library 소개

# %% [markdown]
# ## os
#
# - 환경 변수나 디렉터리, 파일 등의 OS 자원을 제어할 수 있게 해주는 모듈이다

# %% [markdown]
# - 환경 변수 읽어오기

# %%
import os

#os.environ
os.environ['PATH']
# Out:
# 'C:\\Users\\trimu\\Miniconda3\\envs\\tf20;C:\\Users\\trimu\\Miniconda3\\envs\\tf20\\Library\\mingw-w64\\bin;C:\\Users\\trimu\\Miniconda3\\envs\\tf20\\Library\\usr\\bin;C:\\Users\\trimu\\Miniconda3\\envs\\tf20\\Library\\bin;C:\\Users\\trimu\\Miniconda3\\envs\\tf20\\Scripts;C:\\Program Files (x86)\\Common Files\\Oracle\\Java\\javapath;C:\\ProgramData\\Boxstarter;C:\\Users\\trimu\\Anaconda3\\Lib\\site-packages\\PyQt5;C:\\Python36\\Scripts\\;C:\\Python36\\;C:\\Windows\\system32;C:\\Windows;C:\\Windows\\System32\\Wbem;C:\\Windows\\System32\\WindowsPowerShell\\v1.0\\;C:\\Program Files\\Git\\cmd;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\;C:\\Program Files\\MySQL\\MySQL Utilities 1.6\\;C:\\WINDOWS\\System32\\OpenSSH\\;C:\\Program Files\\dotnet\\;C:\\ProgramData\\chocolatey\\bin;C:\\Program Files (x86)\\Yarn\\bin\\;C:\\Program Files\\Pandoc\\;C:\\Program Files (x86)\\Graphviz2.38\\bin;C:\\Users\\trimu\\AppData\\Local\\atom\\bin;C:\\Program Files\\Intel\\WiFi\\bin\\;C:\\Program Files\\Common Files\\Intel\\WirelessCommon\\;C:\\WINDOWS\\system32;C:\\WINDOWS;C:\\WINDOWS\\System32\\Wbem;C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\;C:\\WINDOWS\\System32\\OpenSSH\\;C:\\Program Files\\Java\\jdk-14.0.2\\bin;C:\\Program Files\\nodejs\\;C:\\Program Files\\Go\\bin;C:\\Users\\trimu\\AppData\\Roaming\\Python\\Python39\\Scripts;C:\\Users\\trimu\\AppData\\Roaming\\Python\\xgboost;c:\\Program Files (x86)\\Intel\\Intel(R) Management Engine Components\\DAL;c:\\Program Files\\Intel\\Intel(R) Management Engine Components\\DAL;C:\\Program Files\\MySQL\\MySQL Shell 8.0\\bin\\;C:\\Program Files\\mingw-w64\\x86_64-8.1.0-posix-seh-rt_v6-rev0\\mingw64\\bin;C:\\Users\\trimu\\AppData\\Local\\Programs\\Microsoft VS Code\\bin;C:\\Windows\\System32;C:\\Users\\trimu\\AppData\\Local\\Google\\Cloud SDK\\google-cloud-sdk\\bin;C:\\Users\\trimu\\AppData\\Local\\Microsoft\\WindowsApps;C:\\Users\\trimu\\AppData\\Roaming\\npm;C:\\Users\\trimu\\go\\bin;C:\\Users\\trimu\\AppData\\Roaming\\Python\\xgboost;'

# %% [markdown]
# - 현재 workding 디랙토리

# %%
current_directory = os.getcwd()
current_directory
# Out:
# 'C:\\Users\\trimu\\OneDrive\\AlgorithmPython-BespinGlobal\\Notebooks'

# %% [markdown]
# - working 디렉토리 변경

# %%
os.chdir("C:\\Users\\trimu\\OneDrive\\AlgorithmPython-BespinGlobal\\Notebooks\\images")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\trimu\\OneDrive\\AlgorithmPython-BespinGlobal\\Notebooks\\images'

# %% [markdown]
# - 현재 디렉토리의 파일 목록

# %%
os.listdir()
# Out:
# ['Animation.gif',
#  'Animation2.gif',
#  'cropped-png.png',
#  'dict1.png',
#  'dog.0.jpg',
#  'image_at_epoch_0000.png',
#  'image_at_epoch_0005.png',
#  'image_at_epoch_0010.png',
#  'image_at_epoch_0015.png',
#  'image_at_epoch_0020.png',
#  'image_at_epoch_0025.png',
#  'image_at_epoch_0030.png',
#  'image_at_epoch_0040.png',
#  'image_at_epoch_0045.png',
#  'image_at_epoch_0050.png']

# %% [markdown]
# - 다시 이전 directory로 경로 변경

# %%
os.chdir(current_directory)
os.getcwd()
# Out:
# 'C:\\Users\\trimu\\OneDrive\\AlgorithmPython-BespinGlobal\\Notebooks'

# %% [markdown]
# ## sys.path
#
# - 파이썬 모듈들이 저장되어 있는 위치를 나타낸다. 즉 이 위치에 있는 파이썬 모듈은 경로에 상관없이 어디에서나 불러올 수 있다.

# %%
import sys

sys.path
# Out:
# ['C:\\Users\\trimu\\OneDrive\\AlgorithmPython-BespinGlobal\\Notebooks',
#  'C:\\Users\\trimu\\Miniconda3\\envs\\tf20\\python39.zip',
#  'C:\\Users\\trimu\\Miniconda3\\envs\\tf20\\DLLs',
#  'C:\\Users\\trimu\\Miniconda3\\envs\\tf20\\lib',
#  'C:\\Users\\trimu\\Miniconda3\\envs\\tf20',
#  '',
#  'C:\\Users\\trimu\\AppData\\Roaming\\Python\\Python39\\site-packages',
#  'C:\\Users\\trimu\\Miniconda3\\envs\\tf20\\lib\\site-packages',
#  'C:\\Users\\trimu\\Miniconda3\\envs\\tf20\\lib\\site-packages\\win32',
#  'C:\\Users\\trimu\\Miniconda3\\envs\\tf20\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\trimu\\Miniconda3\\envs\\tf20\\lib\\site-packages\\Pythonwin']

# %% [markdown]
# - 상위 폴더의 파일을 import 해 본다

# %%
from boilerplate import hello
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 from boilerplate import hello
#
# ModuleNotFoundError: No module named 'boilerplate'

# %% [markdown]
# - 상위 경로 추가

# %%
sys.path.append("../")
sys.path
# Out:
# ['C:\\Users\\trimu\\OneDrive\\AlgorithmPython-BespinGlobal\\Notebooks',
#  'C:\\Users\\trimu\\Miniconda3\\envs\\tf20\\python39.zip',
#  'C:\\Users\\trimu\\Miniconda3\\envs\\tf20\\DLLs',
#  'C:\\Users\\trimu\\Miniconda3\\envs\\tf20\\lib',
#  'C:\\Users\\trimu\\Miniconda3\\envs\\tf20',
#  '',
#  'C:\\Users\\trimu\\AppData\\Roaming\\Python\\Python39\\site-packages',
#  'C:\\Users\\trimu\\Miniconda3\\envs\\tf20\\lib\\site-packages',
#  'C:\\Users\\trimu\\Miniconda3\\envs\\tf20\\lib\\site-packages\\win32',
#  'C:\\Users\\trimu\\Miniconda3\\envs\\tf20\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\trimu\\Miniconda3\\envs\\tf20\\lib\\site-packages\\Pythonwin',
#  '../']

# %% [markdown]
# - 경로 추가 후 상위 폴더의 파일 import

# %%
from boilerplate import hello
hello()
# Out:
# Hello Python

# %% [markdown]
# ## pickle

# %% [markdown]
# - pickle 파일 저장

# %%
import pickle

f = open("test.pkl", 'wb')
data = {1: 'python', 2: 'you need'}

pickle.dump(data, f)
f.close()

# %% [markdown]
# - pickle 파일 읽기

# %%
f = open("test.pkl", 'rb')

data = pickle.load(f)
print(data)
# Out:
# {1: 'python', 2: 'you need'}

# %% [markdown]
# ## time
#
# - ``time.time()``
#     - ``UTC``(Universal Time Coordinated 협정 세계 표준시)를 사용하여 현재 시간을 실수 형태로 돌려주는 함수
#     - 1970년 1월 1일 0시 0분 0초를 기준으로 지난 시간을 초 단위로 돌려준다
#
#
# - ``time.localtime``
#     - ``time.time()``이 돌려준 실수 값을 사용해서 연도, 월, 일, 시, 분, 초, ... 의 형태로 바꾸어 주는 함수
#
#
#
# - ``time.strftime``('출력할 형식 포맷 코드', ``time.localtime(time.time())``) - string from time
#
# ```
# %x  날짜를 출력, 현재 시간대 기준
# %c  날짜, 요일, 시간을 출력, 현재 시간대 기준
# %Y  네 자릿수 연도
# %m  숫자 월
# %d  일
# %H  시간(24시간)
# %M  분
# %S  초
# %z  시간대
# %a  요일 줄임말
# %A  요일
# %b  월 줄임말
# %B  월
# %I  시간(12시간)
# %p  AM, PM
# ```

# %%
import time

time.time()
# Out:
# 1662252373.0329106

# %% [markdown]
# - 지역 시간

# %%
time.localtime(time.time())
# Out:
# time.struct_time(tm_year=2022, tm_mon=9, tm_mday=4, tm_hour=9, tm_min=46, tm_sec=14, tm_wday=6, tm_yday=247, tm_isdst=0)

# %% [markdown]
# - 날짜를 출력, 현재 시간대 기준

# %%
time.strftime('%x', time.localtime(time.time()))
# Out:
# '09/04/22'

# %% [markdown]
# - 날짜, 요일, 시간을 출력, 현재 시간대 기준

# %%
time.strftime('%c', time.localtime(time.time()))
# Out:
# 'Sun Sep  4 09:46:16 2022'

# %% [markdown]
# - 연월일 시분초 출력

# %%
time.strftime('%Y-%m-%d-%H:%M:%S %A', time.localtime(time.time()))
# Out:
# '2022-09-04-09:46:18 Sunday'

# %% [markdown]
# ## random
#
# - random은 난수(규칙이 없는 임의의 수)를 발생시키는 모듈이다

# %%
import random

random.random()
# Out:
# 0.2512541532750191

# %% [markdown]
# - random 정수 발생

# %%
random.randint(1, 10)
# Out:
# 9

# %% [markdown]
# ## Pillow
#
# - ``PIL(Python Image Library)`` 은 ``Pillow`` 의 old name
#
#
#     - 설치는 pip install pillow
#     - 사용은 import PIL

# %% [markdown]
# ### image 를 읽어서 display
#
# - ``Image.open()`` : image file open
#
#
# - internet 상의 image 는 byte code 로 전송되므로 ``BytesIO`` 를 이용하여 binary 로 변환

# %%
import requests
from PIL import Image
from io import BytesIO

# %% [markdown]
# - 인터넷상의 임의의 이미지 가져오기

# %%
url = "https://c.files.bbci.co.uk/12A9B/production/_111434467_gettyimages-1143489763.jpg"

response = requests.get(url)
Image.open(BytesIO(response.content)).resize((300, 200))
# Out:
# <PIL.Image.Image image mode=RGB size=300x200 at 0x223666A3DC0>

# %% [markdown]
# - 저장되어 있는 이미지 불러오기

# %%
img = Image.open("images/dog.0.jpg")
img = img.resize((300, 200))
img
# Out:
# <PIL.Image.Image image mode=RGB size=300x200 at 0x2236970FBB0>

# %% [markdown]
# - 이미지 크기, mode 출력

# %%
print("Size: {}\nMode: {}".format(img.size, img.mode))
# Out:
# Size: (300, 200)
# Mode: RGB

# %% [markdown]
# - 위의 두가지 경우를 하나의 함수로 통합

# %%
path = "images/dog.0.jpg"
url = "https://c.files.bbci.co.uk/12A9B/production/_111434467_gettyimages-1143489763.jpg"

def image_load(file_path):
    if 'http' in file_path:
        response = requests.get(url)
        img = Image.open(BytesIO(response.content)).resize((300, 200))
    else:
        img = Image.open("images/dog.0.jpg").resize((300, 200))
        
    return img
        
img = image_load(url)
img
# Out:
# <PIL.Image.Image image mode=RGB size=300x200 at 0x2236677BC10>

# %% [markdown]
# ### PIL 에 사전 정의된 Image Filter 를 이용하여 image 변환
#
# - ImageFilter.BLUR
# - CONTOUR
# - DETAIL
# - EDGE_ENHANCE
# - EDGE_ENHANCE_MORE
# - EMBOSS
# - FIND_EDGES
# - SHARPEN
# - SMOOTH
# - SMOOTH_MORE

# %% [markdown]
# - 사진 흐릿하게 만들기

# %%
from PIL import ImageFilter

img.filter(ImageFilter.BLUR)
# Out:
# <PIL.Image.Image image mode=RGB size=300x200 at 0x2236677B820>

# %% [markdown]
# - 사진 윤곽선

# %%
img.filter(ImageFilter.CONTOUR)
# Out:
# <PIL.Image.Image image mode=RGB size=300x200 at 0x223666AE790>

# %% [markdown]
# - 엠보싱 효과

# %%
img.filter(ImageFilter.EMBOSS)
# Out:
# <PIL.Image.Image image mode=RGB size=300x200 at 0x22368387640>

# %% [markdown]
# - 흑백으로 변환

# %%
grayscale = img.convert('L')    # L : black and white mode
grayscale
# Out:
# <PIL.Image.Image image mode=L size=300x200 at 0x2236677B7C0>

# %% [markdown]
# - image 회전

# %%
img.rotate(180)
# Out:
# <PIL.Image.Image image mode=RGB size=300x200 at 0x2236677BD90>

# %% [markdown]
# ### PIL 을 이용한 image 자르기
#
# ```img.crop((left, upper, right, lower))```  - left/upper corner, right/lower corner

# %%
cropped = img.crop((100, 50, 400, 300))    # cropping (left, upper, right, lower) pixel coordinates
cropped
# Out:
# <PIL.Image.Image image mode=RGB size=300x250 at 0x2236677B100>

# %% [markdown]
# - image 저장

# %%
cropped.save('images/cropped-png.png')

# %%
img = Image.open('images/cropped-png.png')
print(img.format)
# Out:
# PNG

# %% [markdown]
# # Python 을 이용하여 zipfile handling 하는 방법
#
# ### zipfile
# - zip archive object 를 생성하고 **개별 file**을 add
#
# ### shutil
# - **전체 directory**를 빠르게 compress

# %% [markdown]
# - sample file 2 개 생성

# %%
f = open('new_file_1.txt', 'w')
f.write('이것은 첫번째 테스트 file 입니다.')
f.close()

f = open('new_file_2.txt', 'w')
f.write('두번째 테스트 file 입니다')
f.close()

# %% [markdown]
# - empty zipfile object 생성

# %%
import zipfile

comp_file = zipfile.ZipFile('new_compressed_file.zip', 'w')

# %% [markdown]
# - empty object 에 압축할 file 추가

# %%
comp_file.write('new_file_1.txt')
comp_file.write('new_file_2.txt')

comp_file.close()

# %% [markdown]
# ## Extract from zipfile

# %% [markdown]
# - 읽어들일 zipfile object 생성

# %%
zip_object = zipfile.ZipFile('new_compressed_file.zip', 'r')

# %% [markdown]
# - 새로운 directory 에 모든 file 압축 해제

# %%
zip_object.extractall('unzipped_content')

# %% [markdown]
# - 개별 file 단위로 압축 해제 (file name, 저장 directory)

# %%
zip_object.extract('new_file_1.txt', 'unzipped_content_2')
# Out:
# 'unzipped_content_2\\new_file_1.txt'

# %% [markdown]
# ## shutil Library

# %% [markdown]
# - make_archive (압축 file name, format, source directory)

# %%
import shutil

shutil.make_archive('zipped_content3', 'zip', 'unzipped_content')
# Out:
# 'C:\\Users\\trimu\\OneDrive\\AlgorithmPython-BespinGlobal\\Notebooks\\zipped_content3.zip'

# %% [markdown]
# - archived file 압축 해제 : unpack(압축해제할 filename, target directory, format)

# %%
shutil.unpack_archive('zipped_content3.zip', 'unzipped_content_3', 'zip')
